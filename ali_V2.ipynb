# %% [markdown]
# ## 0 - Import Modules and Data

# %%
# Import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_auc_score, roc_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV


import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.svm import SVC

from scipy.stats import zscore

from imblearn.over_sampling import SMOTE

import os
import joblib


from catboost import CatBoostClassifier
import optuna
from optuna.integration import CatBoostPruningCallback
from sklearn.metrics import f1_score

import warnings
from optuna.exceptions import ExperimentalWarning

warnings.filterwarnings("ignore", category=ExperimentalWarning)

# Plotting style
ftsize_title = 20
ftsize_axis = 16
sns.set_style('whitegrid')
sns.set_palette("viridis")

# %%
def performance_display(y_test, y_pred, title):
    """Function that displays a beautiful confusion matrix

    Args:
        y_test (pd.DataFrame): True label values of testing set
        y_pred (pd.DataFrame): Predicted label values of testing set
    """
    # Compute confusion matrix
    cm = confusion_matrix(y_true=y_test, y_pred=y_pred)

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted', fontsize=ftsize_axis)
    plt.ylabel('Actual', fontsize=ftsize_axis)
    # Invert y axis
    plt.gca().invert_yaxis()
    title = 'Confusion Matrix - ' + title
    plt.title(title, fontsize=ftsize_title, fontweight='bold')
    plt.show()
    
    # Print classification report
    report = classification_report(y_true=y_test, y_pred=y_pred)
    print('Classification Report:')
    print(report)

# %%
def create_submission_file(X_test, filename="submission", model_name="rf.pkl"):
    # Load trained model
    model = joblib.load(f"models/{model_name}")
    print(f"Model loaded from models/{model_name}")

    # Predict TARGET values
    y_pred = model.predict(X_test)

    # Create submission DataFrame
    submission_df = pd.DataFrame({
        "ID": X_test['ID'],
        "TARGET": y_pred.astype(bool)  # Convert to True/False
    })

    # Save to CSV
    filename = f"submissions/{filename}.csv"
    submission_df.to_csv(filename, index=False)
    print(f"Submission file saved as {filename}")

# %%
df_train = pd.read_csv("data/train.csv")
df_test = pd.read_csv("data/test.csv")


# Step 1: Load original training and test data
df_train = pd.read_csv("data/train.csv")
df_test = pd.read_csv("data/test.csv")
df_extra = pd.read_csv("data/extra.csv")

df_train['FROM_EXTRA'] = 0
df_extra['FROM_EXTRA'] = 1

df_test['FROM_EXTRA'] = 0

df_train_full = pd.concat([df_train, df_extra], axis=0).reset_index(drop=True)

X = df_train_full.drop('TARGET', axis=1)
y = df_train_full['TARGET']


print(f"Combined X shape: {X.shape}")
print(f"Combined y shape: {y.shape}")
print(y.value_counts())
# Out:
# Combined X shape: (370132, 325)
# Combined y shape: (370132,)
# TARGET
# False    337115
# True      33017
# Name: count, dtype: int64

# %%
# Compute class weights
pos_weight = (len(y) - y.sum()) / y.sum()
class_weights = [1, pos_weight]

print("Using class weights:", class_weights)
# Out:
# Using class weights: [1, np.float64(10.210346185298482)]

# %%
# Drop ID from training (keep it only for submission)
X_final = X.drop("ID", axis=1)
y_final = y
X_test_final = df_test.drop("ID", axis=1)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X_final, 
    y_final,
    test_size=0.2,
    stratify=y_final,
    random_state=42
)

print(X_train.shape, X_val.shape)
# Out:
# (296105, 324) (74027, 324)

# %%
def objective(trial):

    # params = {
    #     "depth": trial.suggest_int("depth", 8, 12),
    #     "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1, log=True),
    #     "iterations": trial.suggest_int("iterations", 1000, 5000),
    #     "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 20, log=True),
    #     "bagging_temperature": trial.suggest_float("bagging_temperature", 0.01, 2, log=True),
    #     "subsample": trial.suggest_float("subsample", 0.7, 1.0),
    #     "rsm": trial.suggest_float("rsm", 0.7, 1.0),
    #     "class_weights": [1, trial.suggest_int("pos_weight", 5, 20)],  # optimize imbalance
    #     "loss_function": "Logloss",
    #     "eval_metric": "F1",
    #     "random_state": 42,
    #     "verbose": False
    # }

    params = {
        "depth": trial.suggest_int("depth", 6, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.2, log=True),
        "iterations": trial.suggest_int("iterations", 1000, 6000),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 30, log=True),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.01, 2, log=True),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "rsm": trial.suggest_float("rsm", 0.5, 1.0),
        "border_count": trial.suggest_int("border_count", 32, 255),  # binning granularity
        # "grow_policy": trial.suggest_categorical("grow_policy", ["SymmetricTree", "Depthwise", "Lossguide"]),
        "sampling_frequency": trial.suggest_categorical("sampling_frequency", ["PerTree", "PerTreeLevel"]),
        "one_hot_max_size": trial.suggest_int("one_hot_max_size", 2, 10),  # for categorical features
        "class_weights": [1, trial.suggest_int("pos_weight", 5, 20)],
        "loss_function": "Logloss",
        "eval_metric": "F1",
        "random_state": 42,
        "verbose": False
    }

    model = CatBoostClassifier(**params)

    # pruning callback cuts bad trials early
    pruning_callback = CatBoostPruningCallback(trial, "F1")

    model.fit(
        X_train, y_train,
        eval_set=(X_val, y_val),
        early_stopping_rounds=60,
        verbose=False,
        callbacks=[pruning_callback]
    )

    # Get predicted probabilities
    probs = model.predict_proba(X_val)[:, 1]

    # Sweep thresholds from 0.1 to 0.9
    thresholds = np.linspace(0.1, 0.9, 81)
    f1s = [f1_score(y_val, probs > t) for t in thresholds]

    # Use the best F1 score
    score = max(f1s)

    # Save the best threshold for this trial
    best_threshold = thresholds[np.argmax(f1s)]
    trial.set_user_attr("best_threshold", best_threshold)

    return score

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=300, show_progress_bar=True)

print("Best F1:", study.best_value)
print("Best Params:", study.best_params)
best_threshold = study.best_trial.user_attrs["best_threshold"]
print(f"Best threshold: {best_threshold:.3f}")
# Out:
# [I 2025-11-04 18:33:10,951] A new study created in memory with name: no-name-08884a01-27b2-40af-bcc3-6af14bfa21f3
#   0%|          | 0/300 [00:00<?, ?it/s]
# [I 2025-11-04 18:33:40,039] Trial 0 finished with value: 0.41896972495217993 and parameters: {'depth': 8, 'learning_rate': 0.09246008011205867, 'iterations': 3953, 'l2_leaf_reg': 7.397220147476662, 'bagging_temperature': 0.05735666710836515, 'subsample': 0.8601843632598398, 'rsm': 0.8180459393178633, 'border_count': 230, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 9}. Best is trial 0 with value: 0.41896972495217993.
# [I 2025-11-04 18:33:57,733] Trial 1 finished with value: 0.40376497432972047 and parameters: {'depth': 12, 'learning_rate': 0.19053303745145242, 'iterations': 1907, 'l2_leaf_reg': 3.1219562082146575, 'bagging_temperature': 0.057686698851045014, 'subsample': 0.8929240962808016, 'rsm': 0.7143114131433703, 'border_count': 117, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 6, 'pos_weight': 16}. Best is trial 0 with value: 0.41896972495217993.
# [I 2025-11-04 18:34:20,629] Trial 2 finished with value: 0.40998521551233935 and parameters: {'depth': 12, 'learning_rate': 0.028094673554749684, 'iterations': 2564, 'l2_leaf_reg': 2.657823142424753, 'bagging_temperature': 0.05556129935021106, 'subsample': 0.745981075536635, 'rsm': 0.5139322988259989, 'border_count': 224, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 4, 'pos_weight': 8}. Best is trial 0 with value: 0.41896972495217993.
# [I 2025-11-04 18:34:46,773] Trial 3 finished with value: 0.42035259426563776 and parameters: {'depth': 7, 'learning_rate': 0.03297816201495235, 'iterations': 2905, 'l2_leaf_reg': 5.929416861557359, 'bagging_temperature': 0.18188120598459911, 'subsample': 0.5773700815327901, 'rsm': 0.6623621762596292, 'border_count': 34, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 5, 'pos_weight': 6}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:34:55,556] Trial 4 finished with value: 0.41777940369489663 and parameters: {'depth': 6, 'learning_rate': 0.18780276548476035, 'iterations': 4803, 'l2_leaf_reg': 10.55248873572482, 'bagging_temperature': 0.6197395211968048, 'subsample': 0.7512378180185149, 'rsm': 0.5066400225989529, 'border_count': 120, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 8, 'pos_weight': 19}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:35:45,899] Trial 5 finished with value: 0.4146595646132469 and parameters: {'depth': 11, 'learning_rate': 0.010226010666978876, 'iterations': 2209, 'l2_leaf_reg': 4.952483567307519, 'bagging_temperature': 1.1457663572436383, 'subsample': 0.5431382832045925, 'rsm': 0.6863102265479619, 'border_count': 245, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 3, 'pos_weight': 16}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:35:59,191] Trial 6 finished with value: 0.41838058180470633 and parameters: {'depth': 7, 'learning_rate': 0.14038148506134898, 'iterations': 2136, 'l2_leaf_reg': 1.8941116750327207, 'bagging_temperature': 0.1916105649755749, 'subsample': 0.5532882951451845, 'rsm': 0.9290383760185823, 'border_count': 245, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 18}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:00,067] Trial 7 finished with value: 0.3841031378189761 and parameters: {'depth': 10, 'learning_rate': 0.05918510142150431, 'iterations': 3785, 'l2_leaf_reg': 27.936233507621377, 'bagging_temperature': 0.014834843311451459, 'subsample': 0.9328546640777926, 'rsm': 0.9901051020508419, 'border_count': 43, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 4, 'pos_weight': 8}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:21,321] Trial 8 finished with value: 0.4058476244025864 and parameters: {'depth': 12, 'learning_rate': 0.04193687392264377, 'iterations': 2210, 'l2_leaf_reg': 1.4844260098081852, 'bagging_temperature': 0.030995069561068646, 'subsample': 0.8994322029667329, 'rsm': 0.6669992016606779, 'border_count': 71, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 10, 'pos_weight': 17}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:22,169] Trial 9 finished with value: 0.320964142240738 and parameters: {'depth': 12, 'learning_rate': 0.00933628749362533, 'iterations': 1210, 'l2_leaf_reg': 1.059879949135327, 'bagging_temperature': 0.14000782536858147, 'subsample': 0.9716187842092572, 'rsm': 0.5151105908126195, 'border_count': 55, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 8, 'pos_weight': 12}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:22,987] Trial 10 finished with value: 0.3810917070494651 and parameters: {'depth': 9, 'learning_rate': 0.020490878559301928, 'iterations': 5769, 'l2_leaf_reg': 17.530419516093918, 'bagging_temperature': 0.31302927399751207, 'subsample': 0.6591554842453595, 'rsm': 0.8080766204470428, 'border_count': 179, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 2, 'pos_weight': 5}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:23,824] Trial 11 finished with value: 0.38248653711074687 and parameters: {'depth': 8, 'learning_rate': 0.0803619330356383, 'iterations': 3712, 'l2_leaf_reg': 7.878520134498352, 'bagging_temperature': 0.09700731813579473, 'subsample': 0.8000089976639774, 'rsm': 0.7941237494034761, 'border_count': 183, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 9}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:24,612] Trial 12 finished with value: 0.38012898401719786 and parameters: {'depth': 8, 'learning_rate': 0.08738411063095397, 'iterations': 3222, 'l2_leaf_reg': 6.213019925268056, 'bagging_temperature': 0.41559188069886566, 'subsample': 0.6321348337872085, 'rsm': 0.6191269954461027, 'border_count': 174, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 2, 'pos_weight': 5}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:25,495] Trial 13 finished with value: 0.36409191781802563 and parameters: {'depth': 6, 'learning_rate': 0.017809390486320915, 'iterations': 4527, 'l2_leaf_reg': 12.216175941856577, 'bagging_temperature': 0.012105059312207674, 'subsample': 0.8344645090079802, 'rsm': 0.8676229529718253, 'border_count': 91, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 11}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:26,276] Trial 14 finished with value: 0.36083095592076186 and parameters: {'depth': 8, 'learning_rate': 0.043099232737897966, 'iterations': 2982, 'l2_leaf_reg': 4.059838748952229, 'bagging_temperature': 0.02710763241266158, 'subsample': 0.6540180761144414, 'rsm': 0.5987654219612744, 'border_count': 145, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 7}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:27,018] Trial 15 finished with value: 0.3709435846230654 and parameters: {'depth': 7, 'learning_rate': 0.08399002893596806, 'iterations': 4486, 'l2_leaf_reg': 8.625186297609886, 'bagging_temperature': 0.08048052780578614, 'subsample': 0.5086323631434452, 'rsm': 0.7670095002169631, 'border_count': 33, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 7, 'pos_weight': 10}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:27,852] Trial 16 finished with value: 0.3704331609731288 and parameters: {'depth': 9, 'learning_rate': 0.017518763432308525, 'iterations': 4010, 'l2_leaf_reg': 18.54637730526757, 'bagging_temperature': 0.2022206545751958, 'subsample': 0.7253863300036688, 'rsm': 0.8530181604709266, 'border_count': 211, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 6}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:28,679] Trial 17 finished with value: 0.3793123441757987 and parameters: {'depth': 7, 'learning_rate': 0.11783243204210225, 'iterations': 5602, 'l2_leaf_reg': 6.082588289862123, 'bagging_temperature': 1.1743073523478702, 'subsample': 0.8370022523922424, 'rsm': 0.5967337914422598, 'border_count': 143, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 3, 'pos_weight': 13}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:29,479] Trial 18 finished with value: 0.3649990033884792 and parameters: {'depth': 10, 'learning_rate': 0.005365601231079238, 'iterations': 5165, 'l2_leaf_reg': 3.7079564003121943, 'bagging_temperature': 0.03125280775833257, 'subsample': 0.6062808706471582, 'rsm': 0.8708270377895209, 'border_count': 79, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 5, 'pos_weight': 7}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:30,404] Trial 19 finished with value: 0.383906214432051 and parameters: {'depth': 7, 'learning_rate': 0.05269724340157701, 'iterations': 1235, 'l2_leaf_reg': 14.088033831702745, 'bagging_temperature': 1.8840488539957378, 'subsample': 0.9920234620788118, 'rsm': 0.7248273229532676, 'border_count': 205, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 10, 'pos_weight': 14}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:31,310] Trial 20 finished with value: 0.37980651181063696 and parameters: {'depth': 9, 'learning_rate': 0.029455988543282786, 'iterations': 2800, 'l2_leaf_reg': 2.1281935500099034, 'bagging_temperature': 0.12533595329566208, 'subsample': 0.6960176079554845, 'rsm': 0.6425159399148881, 'border_count': 103, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 3, 'pos_weight': 10}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:36:51,734] Trial 21 finished with value: 0.4199024848734066 and parameters: {'depth': 7, 'learning_rate': 0.13508694714008065, 'iterations': 3397, 'l2_leaf_reg': 2.309298646800816, 'bagging_temperature': 0.3515799330399474, 'subsample': 0.5765072438174919, 'rsm': 0.9531601211598452, 'border_count': 252, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 19}. Best is trial 3 with value: 0.42035259426563776.
# [I 2025-11-04 18:37:07,101] Trial 22 finished with value: 0.4204437022900763 and parameters: {'depth': 6, 'learning_rate': 0.11966791384226466, 'iterations': 3312, 'l2_leaf_reg': 4.887231512795614, 'bagging_temperature': 0.3342797407679366, 'subsample': 0.5938790561554401, 'rsm': 0.9218809281586728, 'border_count': 228, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:37:18,058] Trial 23 finished with value: 0.4187629817678283 and parameters: {'depth': 6, 'learning_rate': 0.13519088414522779, 'iterations': 3313, 'l2_leaf_reg': 4.531444682484314, 'bagging_temperature': 0.31703974194064, 'subsample': 0.5869814624779554, 'rsm': 0.9835854435437327, 'border_count': 253, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 7, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:37:35,153] Trial 24 finished with value: 0.42013019529293943 and parameters: {'depth': 6, 'learning_rate': 0.1193866278029968, 'iterations': 3403, 'l2_leaf_reg': 2.9548409799575923, 'bagging_temperature': 0.541854069854349, 'subsample': 0.5056505483810737, 'rsm': 0.9305062566314478, 'border_count': 203, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:37:36,028] Trial 25 finished with value: 0.36990130142370514 and parameters: {'depth': 6, 'learning_rate': 0.06491999662054682, 'iterations': 2666, 'l2_leaf_reg': 2.778679778222057, 'bagging_temperature': 0.7149949809450687, 'subsample': 0.507049636195112, 'rsm': 0.9425301255408586, 'border_count': 197, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 7, 'pos_weight': 15}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:37:47,597] Trial 26 finished with value: 0.41837983357807146 and parameters: {'depth': 6, 'learning_rate': 0.036441830761597654, 'iterations': 1703, 'l2_leaf_reg': 3.459361575807101, 'bagging_temperature': 0.6035147938980299, 'subsample': 0.540621827064355, 'rsm': 0.9074657179455831, 'border_count': 158, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:37:48,558] Trial 27 finished with value: 0.37041782984760424 and parameters: {'depth': 6, 'learning_rate': 0.011858093329380598, 'iterations': 4291, 'l2_leaf_reg': 5.55587007799788, 'bagging_temperature': 0.18825112638363123, 'subsample': 0.6238163605404619, 'rsm': 0.8991591144368377, 'border_count': 224, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 8, 'pos_weight': 18}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:37:49,360] Trial 28 finished with value: 0.39014830508474574 and parameters: {'depth': 7, 'learning_rate': 0.11006074767499728, 'iterations': 3165, 'l2_leaf_reg': 4.54518964277902, 'bagging_temperature': 0.4843114587745812, 'subsample': 0.5013625820921646, 'rsm': 0.5665228534819118, 'border_count': 194, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 6, 'pos_weight': 14}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:37:50,408] Trial 29 finished with value: 0.3833375283161339 and parameters: {'depth': 8, 'learning_rate': 0.06970318600470418, 'iterations': 4084, 'l2_leaf_reg': 1.6404002574586922, 'bagging_temperature': 0.25498861375703796, 'subsample': 0.6932131733762406, 'rsm': 0.8306412981440062, 'border_count': 229, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 17}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:07,209] Trial 30 finished with value: 0.41709183673469385 and parameters: {'depth': 6, 'learning_rate': 0.049701365441200414, 'iterations': 3605, 'l2_leaf_reg': 6.92773940710995, 'bagging_temperature': 1.2245358825900885, 'subsample': 0.5730628301886479, 'rsm': 0.7774845677668853, 'border_count': 160, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:17,306] Trial 31 finished with value: 0.415092179090805 and parameters: {'depth': 7, 'learning_rate': 0.1598352728810578, 'iterations': 3540, 'l2_leaf_reg': 2.0661285299295815, 'bagging_temperature': 0.3967584328188341, 'subsample': 0.5798138077361725, 'rsm': 0.9510228420883102, 'border_count': 240, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:18,434] Trial 32 finished with value: 0.39736336741578865 and parameters: {'depth': 7, 'learning_rate': 0.10332462915869708, 'iterations': 2503, 'l2_leaf_reg': 2.627534017458622, 'bagging_temperature': 0.8666955250106733, 'subsample': 0.5356556437827673, 'rsm': 0.9717315493534031, 'border_count': 212, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:19,424] Trial 33 finished with value: 0.39400428265524623 and parameters: {'depth': 6, 'learning_rate': 0.1805918670027133, 'iterations': 3173, 'l2_leaf_reg': 2.611472982657142, 'bagging_temperature': 0.24170355269229274, 'subsample': 0.5903633979303118, 'rsm': 0.9028493471957856, 'border_count': 223, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 18}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:20,381] Trial 34 finished with value: 0.3813271521750849 and parameters: {'depth': 8, 'learning_rate': 0.13173310595035076, 'iterations': 2922, 'l2_leaf_reg': 3.1591038310082133, 'bagging_temperature': 0.5027113468075597, 'subsample': 0.6195172711943375, 'rsm': 0.9991143987517689, 'border_count': 236, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 17}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:25,523] Trial 35 finished with value: 0.41477909845256783 and parameters: {'depth': 7, 'learning_rate': 0.19371057317939802, 'iterations': 2415, 'l2_leaf_reg': 1.254387509735829, 'bagging_temperature': 0.3392647188247932, 'subsample': 0.5620845554721702, 'rsm': 0.7316299064771448, 'border_count': 254, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 3, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:26,365] Trial 36 finished with value: 0.38307719693823056 and parameters: {'depth': 6, 'learning_rate': 0.0986594106344702, 'iterations': 3435, 'l2_leaf_reg': 9.848049272473567, 'bagging_temperature': 0.09483040719516, 'subsample': 0.5241453447210583, 'rsm': 0.6812043866261749, 'border_count': 121, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 4, 'pos_weight': 16}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:27,535] Trial 37 finished with value: 0.3705165896682066 and parameters: {'depth': 7, 'learning_rate': 0.023424232701738854, 'iterations': 2969, 'l2_leaf_reg': 5.2197888855245465, 'bagging_temperature': 0.0583626376000717, 'subsample': 0.6549352320153465, 'rsm': 0.961090613421784, 'border_count': 221, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:28,442] Trial 38 finished with value: 0.3868390390057149 and parameters: {'depth': 6, 'learning_rate': 0.15624960147834774, 'iterations': 1669, 'l2_leaf_reg': 2.32907006110503, 'bagging_temperature': 0.8819727846142547, 'subsample': 0.5552962138354567, 'rsm': 0.9197619540302301, 'border_count': 128, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 4, 'pos_weight': 18}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:29,332] Trial 39 finished with value: 0.3711861501542681 and parameters: {'depth': 10, 'learning_rate': 0.072727157860199, 'iterations': 3810, 'l2_leaf_reg': 1.7276558931842705, 'bagging_temperature': 0.1870324171974095, 'subsample': 0.6881114203573709, 'rsm': 0.8804094215389726, 'border_count': 243, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 7, 'pos_weight': 16}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:32,346] Trial 40 finished with value: 0.35599967503452756 and parameters: {'depth': 11, 'learning_rate': 0.005372063478458711, 'iterations': 4175, 'l2_leaf_reg': 4.029963644431538, 'bagging_temperature': 0.25709054910884166, 'subsample': 0.7864471198411442, 'rsm': 0.6988067703996503, 'border_count': 194, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 9, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:33,378] Trial 41 finished with value: 0.38287153652392947 and parameters: {'depth': 8, 'learning_rate': 0.12221687657905067, 'iterations': 3880, 'l2_leaf_reg': 6.9888573028542655, 'bagging_temperature': 0.048122459770434625, 'subsample': 0.8934157044947761, 'rsm': 0.8290859354768827, 'border_count': 230, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 8}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:34,225] Trial 42 finished with value: 0.37243166532979577 and parameters: {'depth': 7, 'learning_rate': 0.09686752361730137, 'iterations': 5016, 'l2_leaf_reg': 8.363451606595108, 'bagging_temperature': 0.14983511492586665, 'subsample': 0.84672820560311, 'rsm': 0.932722265095857, 'border_count': 217, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 6}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:35,098] Trial 43 finished with value: 0.3817590964786106 and parameters: {'depth': 8, 'learning_rate': 0.16439011993698374, 'iterations': 3379, 'l2_leaf_reg': 3.037664667629628, 'bagging_temperature': 0.1180286467874474, 'subsample': 0.7720288077073358, 'rsm': 0.8862920506037968, 'border_count': 248, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 9}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:35,928] Trial 44 finished with value: 0.3674575086293529 and parameters: {'depth': 7, 'learning_rate': 0.056994648202923145, 'iterations': 3671, 'l2_leaf_reg': 10.992628307057632, 'bagging_temperature': 0.019828224025417604, 'subsample': 0.9227320474017157, 'rsm': 0.7513266332916986, 'border_count': 234, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 12}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:36,708] Trial 45 finished with value: 0.3724462817862808 and parameters: {'depth': 6, 'learning_rate': 0.13614040153287535, 'iterations': 2788, 'l2_leaf_reg': 4.711388759260163, 'bagging_temperature': 0.07048301717210709, 'subsample': 0.5985735048274015, 'rsm': 0.8335869875527387, 'border_count': 204, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 6}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:37,466] Trial 46 finished with value: 0.3724815724815725 and parameters: {'depth': 8, 'learning_rate': 0.08219484976737554, 'iterations': 2292, 'l2_leaf_reg': 6.76597849076085, 'bagging_temperature': 0.5754460695594398, 'subsample': 0.5289954225347026, 'rsm': 0.652800982929742, 'border_count': 60, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 3, 'pos_weight': 11}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:38,297] Trial 47 finished with value: 0.38258607877136486 and parameters: {'depth': 9, 'learning_rate': 0.04252394580711894, 'iterations': 1963, 'l2_leaf_reg': 3.46807303103688, 'bagging_temperature': 0.04575235767389856, 'subsample': 0.7279692219665251, 'rsm': 0.8054664682818926, 'border_count': 241, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 2, 'pos_weight': 9}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:39,185] Trial 48 finished with value: 0.3814025974025974 and parameters: {'depth': 7, 'learning_rate': 0.11601349001963338, 'iterations': 4559, 'l2_leaf_reg': 5.342295431506887, 'bagging_temperature': 0.41141900663755426, 'subsample': 0.8645613596404758, 'rsm': 0.8507990926479089, 'border_count': 185, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 7}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:39,938] Trial 49 finished with value: 0.36967418546365916 and parameters: {'depth': 6, 'learning_rate': 0.0136013338466349, 'iterations': 3095, 'l2_leaf_reg': 9.553881812107683, 'bagging_temperature': 0.1458971324617216, 'subsample': 0.637229141324484, 'rsm': 0.9191543581422497, 'border_count': 102, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 6, 'pos_weight': 5}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:40,948] Trial 50 finished with value: 0.3868434472208057 and parameters: {'depth': 8, 'learning_rate': 0.08642076957312086, 'iterations': 3923, 'l2_leaf_reg': 1.2934900372041984, 'bagging_temperature': 0.7268434485763617, 'subsample': 0.9441826297634174, 'rsm': 0.9714636785417748, 'border_count': 165, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 17}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:38:51,758] Trial 51 finished with value: 0.4169547025650355 and parameters: {'depth': 6, 'learning_rate': 0.1439556077482095, 'iterations': 3385, 'l2_leaf_reg': 4.3207024997457415, 'bagging_temperature': 0.30688323568940934, 'subsample': 0.5691468093416392, 'rsm': 0.9953178773447264, 'border_count': 255, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 7, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:01,407] Trial 52 finished with value: 0.415377817057004 and parameters: {'depth': 6, 'learning_rate': 0.1315576153434278, 'iterations': 3440, 'l2_leaf_reg': 6.003587995774436, 'bagging_temperature': 0.3210252127960586, 'subsample': 0.610483976364762, 'rsm': 0.9746507628463438, 'border_count': 251, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 7, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:05,281] Trial 53 finished with value: 0.4129829235799927 and parameters: {'depth': 7, 'learning_rate': 0.19221200300326696, 'iterations': 2694, 'l2_leaf_reg': 4.744394004181134, 'bagging_temperature': 0.22250942741840873, 'subsample': 0.5887110593486664, 'rsm': 0.947755378468294, 'border_count': 233, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:16,347] Trial 54 finished with value: 0.4165943412601979 and parameters: {'depth': 6, 'learning_rate': 0.09633028752785779, 'iterations': 3181, 'l2_leaf_reg': 3.821278186446639, 'bagging_temperature': 0.16982211436108333, 'subsample': 0.5490535549621234, 'rsm': 0.9282384373928226, 'border_count': 211, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 8, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:17,384] Trial 55 finished with value: 0.2758101667084768 and parameters: {'depth': 7, 'learning_rate': 0.00812906585059054, 'iterations': 3717, 'l2_leaf_reg': 28.017140944490123, 'bagging_temperature': 0.37300166665315587, 'subsample': 0.6707737845922774, 'rsm': 0.9838616640923238, 'border_count': 241, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 18}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:18,150] Trial 56 finished with value: 0.3730873575691807 and parameters: {'depth': 6, 'learning_rate': 0.07409921164534403, 'iterations': 3303, 'l2_leaf_reg': 2.3004962148623993, 'bagging_temperature': 0.4682719216305551, 'subsample': 0.5203569547375593, 'rsm': 0.9424539699826252, 'border_count': 32, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 8}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:18,927] Trial 57 finished with value: 0.3595388620304946 and parameters: {'depth': 9, 'learning_rate': 0.02352691802688644, 'iterations': 2983, 'l2_leaf_reg': 7.56252698897708, 'bagging_temperature': 0.27378700889534097, 'subsample': 0.8051958312539655, 'rsm': 0.8624836153080828, 'border_count': 141, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 4, 'pos_weight': 15}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:19,711] Trial 58 finished with value: 0.3663328822733424 and parameters: {'depth': 6, 'learning_rate': 0.15096944537817525, 'iterations': 4434, 'l2_leaf_reg': 3.037061382936938, 'bagging_temperature': 0.11077366645223483, 'subsample': 0.6439519763350389, 'rsm': 0.8919427623393666, 'border_count': 247, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 10}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:20,682] Trial 59 finished with value: 0.3799270904534062 and parameters: {'depth': 7, 'learning_rate': 0.03538362404706692, 'iterations': 3587, 'l2_leaf_reg': 5.87579869794042, 'bagging_temperature': 0.21526944191536976, 'subsample': 0.6045176456726815, 'rsm': 0.5581445213856906, 'border_count': 204, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 7, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:21,742] Trial 60 finished with value: 0.386843125311479 and parameters: {'depth': 7, 'learning_rate': 0.12000180740162707, 'iterations': 4228, 'l2_leaf_reg': 4.2884240880689894, 'bagging_temperature': 0.7211836515443971, 'subsample': 0.6746796778644637, 'rsm': 0.9553121985665137, 'border_count': 43, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 9, 'pos_weight': 18}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:39,369] Trial 61 finished with value: 0.41671410679722193 and parameters: {'depth': 7, 'learning_rate': 0.1721034443666781, 'iterations': 2062, 'l2_leaf_reg': 1.8478066458524054, 'bagging_temperature': 0.15932783979500537, 'subsample': 0.5529224657326767, 'rsm': 0.9185327927821302, 'border_count': 226, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:40,581] Trial 62 finished with value: 0.39238824217296553 and parameters: {'depth': 8, 'learning_rate': 0.11091939160758767, 'iterations': 1446, 'l2_leaf_reg': 1.9326902620559694, 'bagging_temperature': 0.2740659156082437, 'subsample': 0.5800234674080836, 'rsm': 0.9681459361061967, 'border_count': 216, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:41,552] Trial 63 finished with value: 0.3869100623330365 and parameters: {'depth': 6, 'learning_rate': 0.14308720796721222, 'iterations': 2572, 'l2_leaf_reg': 1.5212329400573872, 'bagging_temperature': 0.08656950826501054, 'subsample': 0.509873008832275, 'rsm': 0.6215193665720584, 'border_count': 246, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 18}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:54,715] Trial 64 finished with value: 0.41479137365213314 and parameters: {'depth': 7, 'learning_rate': 0.06507487103203442, 'iterations': 1037, 'l2_leaf_reg': 2.4902858671909, 'bagging_temperature': 0.5658614667261397, 'subsample': 0.5396464118855022, 'rsm': 0.9095034391082071, 'border_count': 255, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:55,630] Trial 65 finished with value: 0.3910062746920753 and parameters: {'depth': 6, 'learning_rate': 0.09222291676875727, 'iterations': 3988, 'l2_leaf_reg': 3.4580556873848014, 'bagging_temperature': 0.4634040704280138, 'subsample': 0.6144208854089263, 'rsm': 0.9358163339548916, 'border_count': 237, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 5, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:56,443] Trial 66 finished with value: 0.3665531914893617 and parameters: {'depth': 7, 'learning_rate': 0.13066693561065235, 'iterations': 2885, 'l2_leaf_reg': 2.918554997755516, 'bagging_temperature': 0.34060969661262275, 'subsample': 0.5588451086742544, 'rsm': 0.9858467310113369, 'border_count': 229, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 7}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:57,294] Trial 67 finished with value: 0.3773620381686566 and parameters: {'depth': 8, 'learning_rate': 0.10361635375475044, 'iterations': 3062, 'l2_leaf_reg': 2.1685103422120737, 'bagging_temperature': 0.19932929694610813, 'subsample': 0.519833984869849, 'rsm': 0.8709307193831826, 'border_count': 218, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 11}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:39:58,126] Trial 68 finished with value: 0.3860058309037901 and parameters: {'depth': 6, 'learning_rate': 0.15520003389647413, 'iterations': 2266, 'l2_leaf_reg': 4.9939669797143305, 'bagging_temperature': 0.010320155065155616, 'subsample': 0.5833815916059512, 'rsm': 0.7673065444069884, 'border_count': 174, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 5, 'pos_weight': 17}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:40:25,822] Trial 69 finished with value: 0.4189135039212319 and parameters: {'depth': 7, 'learning_rate': 0.050780240875943815, 'iterations': 3739, 'l2_leaf_reg': 17.25320874338696, 'bagging_temperature': 0.033406987428069516, 'subsample': 0.6263710169890752, 'rsm': 0.9582922860095207, 'border_count': 71, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:40:50,872] Trial 70 finished with value: 0.4193844459401579 and parameters: {'depth': 8, 'learning_rate': 0.04792028723043337, 'iterations': 3489, 'l2_leaf_reg': 14.892757535449354, 'bagging_temperature': 0.03430062918394638, 'subsample': 0.6324421178870763, 'rsm': 0.9548183772300308, 'border_count': 57, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 3, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:40:53,892] Trial 71 finished with value: 0.39674034382674706 and parameters: {'depth': 8, 'learning_rate': 0.03341375657865964, 'iterations': 3490, 'l2_leaf_reg': 17.72884124679343, 'bagging_temperature': 0.03476820606639791, 'subsample': 0.6380822681920076, 'rsm': 0.9568970188924745, 'border_count': 67, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 2, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:40:56,036] Trial 72 finished with value: 0.3896992818671454 and parameters: {'depth': 8, 'learning_rate': 0.027252901988628415, 'iterations': 3316, 'l2_leaf_reg': 22.275873442234015, 'bagging_temperature': 0.02146368092353302, 'subsample': 0.6251118589548534, 'rsm': 0.9773825571631751, 'border_count': 46, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 3, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:40:57,515] Trial 73 finished with value: 0.3962591700733606 and parameters: {'depth': 9, 'learning_rate': 0.054986049625838355, 'iterations': 3846, 'l2_leaf_reg': 15.351305776238982, 'bagging_temperature': 0.03607714164113466, 'subsample': 0.7079812773869845, 'rsm': 0.9366876813176246, 'border_count': 80, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 3, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:41:23,249] Trial 74 finished with value: 0.41628486922229313 and parameters: {'depth': 10, 'learning_rate': 0.040122123016886946, 'iterations': 3677, 'l2_leaf_reg': 19.80849003379922, 'bagging_temperature': 0.024349108354825216, 'subsample': 0.5952579226471942, 'rsm': 0.9983536304500783, 'border_count': 41, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 3, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:41:24,076] Trial 75 finished with value: 0.3650827055010733 and parameters: {'depth': 7, 'learning_rate': 0.0489100194220991, 'iterations': 4067, 'l2_leaf_reg': 12.598879126695664, 'bagging_temperature': 0.03989033501474219, 'subsample': 0.7447518577369923, 'rsm': 0.9568385823256293, 'border_count': 54, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 13}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:41:24,915] Trial 76 finished with value: 0.37821041899305724 and parameters: {'depth': 6, 'learning_rate': 0.04761218500129419, 'iterations': 3259, 'l2_leaf_reg': 23.317505641676497, 'bagging_temperature': 0.016073639142654368, 'subsample': 0.5630079203360704, 'rsm': 0.9100567850405209, 'border_count': 80, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:41:25,708] Trial 77 finished with value: 0.33139806473139805 and parameters: {'depth': 7, 'learning_rate': 0.02926773890767978, 'iterations': 3545, 'l2_leaf_reg': 14.151720493370568, 'bagging_temperature': 0.06350316503266659, 'subsample': 0.6718662709781416, 'rsm': 0.7869536980345534, 'border_count': 59, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 18}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:41:26,452] Trial 78 finished with value: 0.374916163648558 and parameters: {'depth': 6, 'learning_rate': 0.06295279519069777, 'iterations': 4368, 'l2_leaf_reg': 15.229089861353696, 'bagging_temperature': 0.049630606871575764, 'subsample': 0.573332777704514, 'rsm': 0.7389960392829212, 'border_count': 72, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 5, 'pos_weight': 9}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:41:27,237] Trial 79 finished with value: 0.38470485606280896 and parameters: {'depth': 9, 'learning_rate': 0.07865633003908741, 'iterations': 3779, 'l2_leaf_reg': 11.297708101535147, 'bagging_temperature': 1.3799462402336413, 'subsample': 0.6447132205321675, 'rsm': 0.9240845394582939, 'border_count': 49, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 5}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:41:28,174] Trial 80 finished with value: 0.36773006913173084 and parameters: {'depth': 8, 'learning_rate': 0.0251179178971141, 'iterations': 4633, 'l2_leaf_reg': 6.425816054430782, 'bagging_temperature': 0.027079310486234343, 'subsample': 0.8765201642071466, 'rsm': 0.703321204514466, 'border_count': 94, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 3, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:41:42,092] Trial 81 finished with value: 0.4202967927237913 and parameters: {'depth': 7, 'learning_rate': 0.10650656391755987, 'iterations': 3100, 'l2_leaf_reg': 9.247056414017292, 'bagging_temperature': 0.37878214652675285, 'subsample': 0.5419278082443559, 'rsm': 0.8963400582167877, 'border_count': 38, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:41:56,488] Trial 82 finished with value: 0.41820064427059367 and parameters: {'depth': 7, 'learning_rate': 0.10743844517127513, 'iterations': 2801, 'l2_leaf_reg': 9.167865946891846, 'bagging_temperature': 0.37833831896703074, 'subsample': 0.5369321378627342, 'rsm': 0.8935027327581335, 'border_count': 39, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:42:04,711] Trial 83 finished with value: 0.41348664111536965 and parameters: {'depth': 7, 'learning_rate': 0.12396706173981603, 'iterations': 3109, 'l2_leaf_reg': 8.716882107817797, 'bagging_temperature': 0.5366289384175262, 'subsample': 0.5015257477855619, 'rsm': 0.8773362981308432, 'border_count': 50, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:42:05,962] Trial 84 finished with value: 0.38670824819873106 and parameters: {'depth': 6, 'learning_rate': 0.019509416506608333, 'iterations': 3249, 'l2_leaf_reg': 7.119624342760492, 'bagging_temperature': 0.8333395198016372, 'subsample': 0.6002024065956488, 'rsm': 0.9626209495958363, 'border_count': 36, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:42:07,379] Trial 85 finished with value: 0.3946530147895336 and parameters: {'depth': 11, 'learning_rate': 0.1794484832434387, 'iterations': 3470, 'l2_leaf_reg': 5.635804587716869, 'bagging_temperature': 0.04256922875391758, 'subsample': 0.6277556961800894, 'rsm': 0.9478442558170137, 'border_count': 70, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:42:08,148] Trial 86 finished with value: 0.3777464788732394 and parameters: {'depth': 7, 'learning_rate': 0.09093223589884267, 'iterations': 3028, 'l2_leaf_reg': 7.7969085061461145, 'bagging_temperature': 0.4344776728038893, 'subsample': 0.5480126625761905, 'rsm': 0.9087866320741602, 'border_count': 53, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 8}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:42:08,953] Trial 87 finished with value: 0.3841074059924685 and parameters: {'depth': 8, 'learning_rate': 0.06910062818078572, 'iterations': 3683, 'l2_leaf_reg': 10.616547607934002, 'bagging_temperature': 0.029923167513597273, 'subsample': 0.5699984229041087, 'rsm': 0.8065549847881535, 'border_count': 61, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 8, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:42:09,845] Trial 88 finished with value: 0.3667354762606901 and parameters: {'depth': 6, 'learning_rate': 0.038135086616423425, 'iterations': 4158, 'l2_leaf_reg': 12.2257590234902, 'bagging_temperature': 0.6601872212686198, 'subsample': 0.8201962738303754, 'rsm': 0.986960203837547, 'border_count': 249, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:42:10,684] Trial 89 finished with value: 0.3729606048547553 and parameters: {'depth': 7, 'learning_rate': 0.04529646414032556, 'iterations': 2840, 'l2_leaf_reg': 20.758433861741242, 'bagging_temperature': 0.24264348079423884, 'subsample': 0.5266104165816434, 'rsm': 0.9413038682359502, 'border_count': 35, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 7, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:42:12,503] Trial 90 finished with value: 0.3956707253616401 and parameters: {'depth': 6, 'learning_rate': 0.05918365936252556, 'iterations': 2636, 'l2_leaf_reg': 24.47547303476696, 'bagging_temperature': 0.07446235680669991, 'subsample': 0.6142924227158924, 'rsm': 0.8362351576728269, 'border_count': 188, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:42:28,826] Trial 91 finished with value: 0.4187748407040565 and parameters: {'depth': 7, 'learning_rate': 0.1150429678056891, 'iterations': 5960, 'l2_leaf_reg': 6.461900704371718, 'bagging_temperature': 0.18250798012314398, 'subsample': 0.5147744392387281, 'rsm': 0.9310446387078117, 'border_count': 241, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:42:39,853] Trial 92 finished with value: 0.4146326467875807 and parameters: {'depth': 7, 'learning_rate': 0.11603621458916576, 'iterations': 3344, 'l2_leaf_reg': 6.325601165966722, 'bagging_temperature': 0.1344815751030284, 'subsample': 0.5113600834470334, 'rsm': 0.9278120140893061, 'border_count': 236, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:42:41,001] Trial 93 finished with value: 0.3919351153758282 and parameters: {'depth': 8, 'learning_rate': 0.1022534818668716, 'iterations': 5549, 'l2_leaf_reg': 5.020015837499327, 'bagging_temperature': 0.17244463653802497, 'subsample': 0.537443514218514, 'rsm': 0.8521360161101126, 'border_count': 228, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:42:56,376] Trial 94 finished with value: 0.4197126291908243 and parameters: {'depth': 7, 'learning_rate': 0.13638967318180242, 'iterations': 5562, 'l2_leaf_reg': 8.217120428857163, 'bagging_temperature': 0.32291543019544294, 'subsample': 0.588278447314457, 'rsm': 0.8997131914764536, 'border_count': 243, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:42:59,399] Trial 95 finished with value: 0.4106536982583126 and parameters: {'depth': 7, 'learning_rate': 0.08184612229963512, 'iterations': 4999, 'l2_leaf_reg': 7.956786228915044, 'bagging_temperature': 0.289504567632036, 'subsample': 0.5848585934844479, 'rsm': 0.8992390543065536, 'border_count': 242, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:43:01,676] Trial 96 finished with value: 0.3785866369258846 and parameters: {'depth': 7, 'learning_rate': 0.031693990068721915, 'iterations': 5781, 'l2_leaf_reg': 10.113220010134581, 'bagging_temperature': 0.3637530988370932, 'subsample': 0.9904800165688694, 'rsm': 0.8853260011880463, 'border_count': 221, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 18}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:43:02,524] Trial 97 finished with value: 0.37587301587301586 and parameters: {'depth': 7, 'learning_rate': 0.1674605938382712, 'iterations': 5284, 'l2_leaf_reg': 7.382960974720114, 'bagging_temperature': 0.10399309887337381, 'subsample': 0.5622306726495018, 'rsm': 0.9144190909080729, 'border_count': 132, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 2, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:43:03,290] Trial 98 finished with value: 0.38043698159012745 and parameters: {'depth': 8, 'learning_rate': 0.14171108228245147, 'iterations': 5862, 'l2_leaf_reg': 8.569597224206156, 'bagging_temperature': 0.22878874181715486, 'subsample': 0.5479846875264589, 'rsm': 0.6774260324110499, 'border_count': 115, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 6}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:43:04,093] Trial 99 finished with value: 0.36874617396627524 and parameters: {'depth': 7, 'learning_rate': 0.12795726509708327, 'iterations': 5497, 'l2_leaf_reg': 6.468698673850966, 'bagging_temperature': 0.4332219187266102, 'subsample': 0.5178850339175955, 'rsm': 0.9292867298507381, 'border_count': 238, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 12}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:43:05,087] Trial 100 finished with value: 0.38100843633509907 and parameters: {'depth': 7, 'learning_rate': 0.11187572090395553, 'iterations': 5951, 'l2_leaf_reg': 16.683311463548197, 'bagging_temperature': 0.017219779353237586, 'subsample': 0.9086895310018225, 'rsm': 0.5355785819410886, 'border_count': 46, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:43:24,636] Trial 101 finished with value: 0.4191850493819859 and parameters: {'depth': 6, 'learning_rate': 0.1397103694726804, 'iterations': 5663, 'l2_leaf_reg': 13.182837010123045, 'bagging_temperature': 0.33344163196570553, 'subsample': 0.5911498747580235, 'rsm': 0.9660468599976304, 'border_count': 251, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:43:25,642] Trial 102 finished with value: 0.3762737935012498 and parameters: {'depth': 6, 'learning_rate': 0.09763992624143131, 'iterations': 5693, 'l2_leaf_reg': 14.259331977535801, 'bagging_temperature': 0.3013978989488351, 'subsample': 0.6038599856956445, 'rsm': 0.9672410013592762, 'border_count': 244, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:43:26,546] Trial 103 finished with value: 0.37781954887218044 and parameters: {'depth': 6, 'learning_rate': 0.15048070290705823, 'iterations': 5483, 'l2_leaf_reg': 9.062384521000853, 'bagging_temperature': 0.32963239976953845, 'subsample': 0.5751900586843285, 'rsm': 0.9523055620649981, 'border_count': 249, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 19}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:43:40,059] Trial 104 finished with value: 0.41829506595017096 and parameters: {'depth': 7, 'learning_rate': 0.12282198819455299, 'iterations': 5825, 'l2_leaf_reg': 11.800049389045963, 'bagging_temperature': 0.05348545392326971, 'subsample': 0.5916209801700729, 'rsm': 0.9386577956437814, 'border_count': 233, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 22 with value: 0.4204437022900763.
# [I 2025-11-04 18:43:41,024] Trial 105 finished with value: 0.390663797384539 and parameters: {'depth': 7, 'learning_rate': 0.13578718484539037, 'iterations': 5617, 'l2_leaf_reg': 13.543255099949059, 'bagging_temperature': 0.4996649415941433, 'subsample': 0.5294183214375099, 'rsm': 0.9769463035827013, 'border_count': 232, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 18}. Best is trial 22 with value: 0.4204437022900763.
# ...
# [I 2025-11-04 18:53:02,102] Trial 266 finished with value: 0.41673075785363545 and parameters: {'depth': 7, 'learning_rate': 0.1754241258468194, 'iterations': 2612, 'l2_leaf_reg': 5.617586776335761, 'bagging_temperature': 0.17542128362361523, 'subsample': 0.5983845298722869, 'rsm': 0.9611955893880552, 'border_count': 225, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:02,946] Trial 267 finished with value: 0.3577289446383099 and parameters: {'depth': 7, 'learning_rate': 0.14515605856129452, 'iterations': 3290, 'l2_leaf_reg': 5.105396361387714, 'bagging_temperature': 0.1507035184458036, 'subsample': 0.5873685955427091, 'rsm': 0.9481128904166791, 'border_count': 101, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 19}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:16,447] Trial 268 finished with value: 0.418929496056355 and parameters: {'depth': 7, 'learning_rate': 0.15986777051109446, 'iterations': 3462, 'l2_leaf_reg': 6.703666724538192, 'bagging_temperature': 1.9354203150186011, 'subsample': 0.574915722369994, 'rsm': 0.982791565685767, 'border_count': 221, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:17,574] Trial 269 finished with value: 0.3943766578249337 and parameters: {'depth': 7, 'learning_rate': 0.1861732136942206, 'iterations': 3431, 'l2_leaf_reg': 5.9007449366313045, 'bagging_temperature': 1.3108908270336161, 'subsample': 0.5709314114226364, 'rsm': 0.9862286218656037, 'border_count': 227, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:27,091] Trial 270 finished with value: 0.41771387143547606 and parameters: {'depth': 7, 'learning_rate': 0.1676502108045122, 'iterations': 3585, 'l2_leaf_reg': 6.603375534124974, 'bagging_temperature': 1.5041045280245808, 'subsample': 0.5788478855613267, 'rsm': 0.7442237407215411, 'border_count': 188, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 9, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:28,014] Trial 271 finished with value: 0.3801605504587156 and parameters: {'depth': 7, 'learning_rate': 0.15751429988774843, 'iterations': 3388, 'l2_leaf_reg': 7.492990847883269, 'bagging_temperature': 0.04005951194173292, 'subsample': 0.599350636156782, 'rsm': 0.99891763867245, 'border_count': 222, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:29,095] Trial 272 finished with value: 0.38637838917461426 and parameters: {'depth': 7, 'learning_rate': 0.019721531026297864, 'iterations': 4092, 'l2_leaf_reg': 8.478150817534793, 'bagging_temperature': 0.03287449066781822, 'subsample': 0.6096274577588618, 'rsm': 0.9750057103283244, 'border_count': 216, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 3, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:29,975] Trial 273 finished with value: 0.3697227654434603 and parameters: {'depth': 7, 'learning_rate': 0.024082270564778803, 'iterations': 3239, 'l2_leaf_reg': 6.191194588395379, 'bagging_temperature': 0.16551722605617636, 'subsample': 0.575073903554788, 'rsm': 0.9777534157098073, 'border_count': 201, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 2, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:31,043] Trial 274 finished with value: 0.3916592195412571 and parameters: {'depth': 7, 'learning_rate': 0.1381591511291078, 'iterations': 3474, 'l2_leaf_reg': 20.697351917647765, 'bagging_temperature': 0.36274377037524225, 'subsample': 0.6624168460052202, 'rsm': 0.8022035761716415, 'border_count': 123, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:37,036] Trial 275 finished with value: 0.415637604716103 and parameters: {'depth': 8, 'learning_rate': 0.15447248366365435, 'iterations': 3761, 'l2_leaf_reg': 6.669479834773991, 'bagging_temperature': 1.105020425310038, 'subsample': 0.5915705673202616, 'rsm': 0.9679212391491062, 'border_count': 116, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:37,857] Trial 276 finished with value: 0.3503620672552326 and parameters: {'depth': 7, 'learning_rate': 0.1839374486941874, 'iterations': 4570, 'l2_leaf_reg': 7.0261176396983585, 'bagging_temperature': 0.2704366158979681, 'subsample': 0.5600917404235477, 'rsm': 0.9572933813934379, 'border_count': 232, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:38,644] Trial 277 finished with value: 0.3739475466950547 and parameters: {'depth': 7, 'learning_rate': 0.1169773623434194, 'iterations': 3128, 'l2_leaf_reg': 15.844622753407492, 'bagging_temperature': 0.9621384775930677, 'subsample': 0.5847124590922538, 'rsm': 0.6938129892658781, 'border_count': 211, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 9}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:39,440] Trial 278 finished with value: 0.3589558631260989 and parameters: {'depth': 7, 'learning_rate': 0.1676675527447103, 'iterations': 3578, 'l2_leaf_reg': 14.028180227286594, 'bagging_temperature': 0.21906016645906168, 'subsample': 0.5079515903372249, 'rsm': 0.6309139413127122, 'border_count': 235, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 19}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:40,223] Trial 279 finished with value: 0.3774258513365068 and parameters: {'depth': 7, 'learning_rate': 0.10435252599785576, 'iterations': 3351, 'l2_leaf_reg': 1.5278279218049224, 'bagging_temperature': 0.31648889091589616, 'subsample': 0.5721316916458548, 'rsm': 0.9887280666545492, 'border_count': 232, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 15}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:41,692] Trial 280 finished with value: 0.40291621575439995 and parameters: {'depth': 7, 'learning_rate': 0.13328339454776109, 'iterations': 3453, 'l2_leaf_reg': 5.646347402382219, 'bagging_temperature': 1.7585955628360426, 'subsample': 0.5604447223746011, 'rsm': 0.9810249879520936, 'border_count': 227, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:44,161] Trial 281 finished with value: 0.36253632509170597 and parameters: {'depth': 7, 'learning_rate': 0.14555023735009245, 'iterations': 3659, 'l2_leaf_reg': 4.961434612541699, 'bagging_temperature': 0.1997261330390285, 'subsample': 0.6288985996290357, 'rsm': 0.7121128741222168, 'border_count': 178, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:45,535] Trial 282 finished with value: 0.3921909972643621 and parameters: {'depth': 9, 'learning_rate': 0.11264108509279154, 'iterations': 3260, 'l2_leaf_reg': 7.155317457317096, 'bagging_temperature': 0.020848099572889814, 'subsample': 0.518922263071343, 'rsm': 0.9667323900176912, 'border_count': 32, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:46,330] Trial 283 finished with value: 0.35050120981679916 and parameters: {'depth': 7, 'learning_rate': 0.12333726097310048, 'iterations': 3536, 'l2_leaf_reg': 7.740347019847384, 'bagging_temperature': 0.058938595117020695, 'subsample': 0.5972650872521041, 'rsm': 0.9365218820196342, 'border_count': 221, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:47,145] Trial 284 finished with value: 0.3775817025681471 and parameters: {'depth': 7, 'learning_rate': 0.19721534373599123, 'iterations': 3685, 'l2_leaf_reg': 4.482556224871316, 'bagging_temperature': 0.14231772144671714, 'subsample': 0.5008255605933031, 'rsm': 0.9504041380668243, 'border_count': 237, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 7, 'pos_weight': 10}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:48,466] Trial 285 finished with value: 0.39840773386408873 and parameters: {'depth': 7, 'learning_rate': 0.16166174263655333, 'iterations': 5759, 'l2_leaf_reg': 6.334092347080932, 'bagging_temperature': 0.24527405322119095, 'subsample': 0.5821323123165989, 'rsm': 0.9627778075325627, 'border_count': 240, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 3, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:49,384] Trial 286 finished with value: 0.38371616078753074 and parameters: {'depth': 8, 'learning_rate': 0.08720370710136097, 'iterations': 3396, 'l2_leaf_reg': 1.7102993969267182, 'bagging_temperature': 0.04579867316931261, 'subsample': 0.5533233491166252, 'rsm': 0.7871475545321966, 'border_count': 247, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 19}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:50,427] Trial 287 finished with value: 0.38245219347581555 and parameters: {'depth': 7, 'learning_rate': 0.1514892781856114, 'iterations': 3191, 'l2_leaf_reg': 17.452777795922113, 'bagging_temperature': 0.02976104378987569, 'subsample': 0.5677296495470057, 'rsm': 0.9744429172125625, 'border_count': 183, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 4, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:51,427] Trial 288 finished with value: 0.382051282051282 and parameters: {'depth': 7, 'learning_rate': 0.13782559086292184, 'iterations': 3807, 'l2_leaf_reg': 2.0321864050227503, 'bagging_temperature': 0.36667642633268693, 'subsample': 0.5226647686846693, 'rsm': 0.8578940204694162, 'border_count': 192, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:52,267] Trial 289 finished with value: 0.35888888888888887 and parameters: {'depth': 7, 'learning_rate': 0.12789513839830524, 'iterations': 5916, 'l2_leaf_reg': 16.00314078276245, 'bagging_temperature': 0.16721552349962643, 'subsample': 0.845901367951597, 'rsm': 0.9340032552299037, 'border_count': 252, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 19}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:55,980] Trial 290 finished with value: 0.41517267408945085 and parameters: {'depth': 7, 'learning_rate': 0.17394653111154096, 'iterations': 3593, 'l2_leaf_reg': 14.427106420895146, 'bagging_temperature': 0.40943975890077333, 'subsample': 0.5317071472762982, 'rsm': 0.9876616155659034, 'border_count': 42, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:57,002] Trial 291 finished with value: 0.3963538873994638 and parameters: {'depth': 7, 'learning_rate': 0.11064292195751879, 'iterations': 3336, 'l2_leaf_reg': 1.3794007968556157, 'bagging_temperature': 0.19088337436728614, 'subsample': 0.6039180530239995, 'rsm': 0.9455551290492485, 'border_count': 243, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:57,766] Trial 292 finished with value: 0.34332122679580307 and parameters: {'depth': 6, 'learning_rate': 0.14210411107206344, 'iterations': 4893, 'l2_leaf_reg': 5.915148707702652, 'bagging_temperature': 0.025256573094583516, 'subsample': 0.5805258159548975, 'rsm': 0.603764191047707, 'border_count': 76, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 6, 'pos_weight': 19}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:58,569] Trial 293 finished with value: 0.37733814888685246 and parameters: {'depth': 8, 'learning_rate': 0.10078136150285903, 'iterations': 3446, 'l2_leaf_reg': 18.825086803945002, 'bagging_temperature': 0.013021058384255643, 'subsample': 0.5113026343853557, 'rsm': 0.957375234099936, 'border_count': 255, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 7}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:53:59,604] Trial 294 finished with value: 0.381893528849219 and parameters: {'depth': 7, 'learning_rate': 0.12512548940927395, 'iterations': 5455, 'l2_leaf_reg': 6.6254708676826946, 'bagging_temperature': 0.2874330481744415, 'subsample': 0.5473645323643298, 'rsm': 0.9265646743519119, 'border_count': 228, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 8, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:54:00,440] Trial 295 finished with value: 0.3690695211016335 and parameters: {'depth': 7, 'learning_rate': 0.16035761405388677, 'iterations': 3474, 'l2_leaf_reg': 8.21814990161179, 'bagging_temperature': 0.3306842883358336, 'subsample': 0.8878495778581574, 'rsm': 0.7750726281303383, 'border_count': 136, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 8}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:54:01,375] Trial 296 finished with value: 0.37724661849175467 and parameters: {'depth': 7, 'learning_rate': 0.13623591929046194, 'iterations': 3857, 'l2_leaf_reg': 1.9095725053469843, 'bagging_temperature': 0.036523218232351634, 'subsample': 0.593226966509317, 'rsm': 0.9707889365846308, 'border_count': 218, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:54:02,155] Trial 297 finished with value: 0.3519556111624871 and parameters: {'depth': 6, 'learning_rate': 0.14911147486275023, 'iterations': 3065, 'l2_leaf_reg': 1.59594542950854, 'bagging_temperature': 1.9578987528374983, 'subsample': 0.5738884155654531, 'rsm': 0.9546090346423206, 'border_count': 37, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 19}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:54:03,142] Trial 298 finished with value: 0.382817949314113 and parameters: {'depth': 7, 'learning_rate': 0.11794166545436799, 'iterations': 3656, 'l2_leaf_reg': 5.36950962143814, 'bagging_temperature': 0.4633266137197133, 'subsample': 0.5628251556801056, 'rsm': 0.9425960073955938, 'border_count': 246, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# [I 2025-11-04 18:54:03,974] Trial 299 finished with value: 0.36445536445536447 and parameters: {'depth': 9, 'learning_rate': 0.018248069045008804, 'iterations': 3262, 'l2_leaf_reg': 1.8306684942935354, 'bagging_temperature': 0.22832523042811492, 'subsample': 0.5876186903821183, 'rsm': 0.9768175154590808, 'border_count': 49, 'sampling_frequency': 'PerTree', 'one_hot_max_size': 5, 'pos_weight': 20}. Best is trial 141 with value: 0.42201487832555795.
# Best F1: 0.42201487832555795
# Best Params: {'depth': 7, 'learning_rate': 0.1283304976830485, 'iterations': 1823, 'l2_leaf_reg': 16.76722489515425, 'bagging_temperature': 0.15779207939492257, 'subsample': 0.5533819675420546, 'rsm': 0.949286187100711, 'border_count': 246, 'sampling_frequency': 'PerTreeLevel', 'one_hot_max_size': 5, 'pos_weight': 20}
# Best threshold: 0.850

# %% [markdown]
# Best Params: {'depth': 8, 'learning_rate': 0.0891298975097704, 'iterations': 2113, 'l2_leaf_reg': 15.020144260249884, 'bagging_temperature': 0.181935508142554, 'subsample': 0.7286665619626174, 'rsm': 0.7086792468056278, 'pos_weight': 6}
#
#
# Best F1: 0.4205530817904851
# Best Params: {'depth': 8, 'learning_rate': 0.027243341395631743, 'iterations': 1621, 'l2_leaf_reg': 11.464256887807908, 'bagging_temperature': 0.10490277228464714, 'subsample': 0.8090584457549639, 'rsm': 0.8224343572178422, 'pos_weight': 7}
# Best threshold: 0.640

# %%
best_params = study.best_params.copy()

# Convert pos_weight to class_weights
pos_weight = best_params.pop("pos_weight")
best_params["class_weights"] = [1, pos_weight]

# Add other fixed parameters
best_params.update({
    "loss_function": "Logloss",
    "eval_metric": "F1",
    "verbose": False,
    "random_state": 42
})

import json

# Save best parameters to a JSON file
with open("parameters/best_catboost_params_v2.json", "w") as f:
    json.dump(best_params, f, indent=2)

print("Saved best parameters to best_catboost_params.json")
# Out:
# Saved best parameters to best_catboost_params.json

# %%
# Load best parameters from JSON
with open("parameters/best_catboost_params_v2.json", "r") as f:
    best_params = json.load(f)

# Train final model using loaded parameters
final_model = CatBoostClassifier(**best_params)
final_model.fit(
    X_final,
    y_final,
    early_stopping_rounds=60,
    verbose=False
)

# %%
joblib.dump(final_model, "models/catboost_tuned_V4.pkl")
print("Model saved as catboost_tuned_V4.pkl")
# Out:
# Model saved as catboost_tuned_V4.pkl

# %%
test_probs = final_model.predict_proba(X_test_final)[:, 1]
test_preds = (test_probs > best_threshold).astype(bool)

submission = pd.DataFrame({
    "ID": df_test["ID"],
    "TARGET": test_preds
})

submission.to_csv("submissions/catboost_tuned_V4.csv", index=False)
print("Saved as catboost_tuned_V4.csv")
print(f"Saved catboost_tuned_V4.csv using threshold {best_threshold:.3f}")
# Out:
# Saved as catboost_tuned_V4.csv
# Saved catboost_tuned_V4.csv using threshold 0.850
